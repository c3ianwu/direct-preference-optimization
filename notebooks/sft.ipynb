# %% [markdown]
# # SFT
#
# Supervised finetuning - used as a precursor to DPO in order to get the policy and reference models "on-distribution", which is recommended if the DPO dataset was not generated by the policy model.

# %%
# !/usr/local/nvidia/bin/nvidia-smi
# Out:
# Fri Jul 14 17:28:46 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.182.03   Driver Version: 470.182.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:80:00.0 Off |                    0 |
# | N/A   66C    P0   375W / 400W |  59346MiB / 81251MiB |     92%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# ...

# %% [markdown]
# ## Train SFT
#
# Balance out smaller batch sizes with more gradient accumulation steps to get a good "virtual" batch size.

# %%
# !python -u train.py model=pythia28 datasets=[hh] loss=sft exp_name=anthropic_dpo_pythia28 gradient_accumulation_steps=4 batch_size=32 eval_batch_size=32 trainer=FSDPTrainer sample_during_eval=false model.fsdp_policy_mp=bfloat16
# Out:
# seed: 0
# exp_name: anthropic_dpo_pythia28
# batch_size: 32
# eval_batch_size: 32
# debug: false
# fsdp_port: 12355
# datasets:
# - hh
# wandb:
#   enabled: true
#   entity: ianyhwu
#   project: c3GenAI
# local_dirs:
# - /scr-ssd
# - /scr
# - .cache
# sample_during_eval: false
# n_eval_model_samples: 16
# do_first_eval: true
# local_run_dir: .cache/c3/anthropic_dpo_pythia28_2023-07-14_12-23-01_897813
# lr: 5.0e-07
# gradient_accumulation_steps: 4
# max_grad_norm: 10.0
# max_length: 512
# max_prompt_length: 256
# n_epochs: 1
# n_examples: null
# n_eval_examples: 256
# trainer: FSDPTrainer
# optimizer: RMSprop
# warmup_steps: 150
# activation_checkpointing: false
# eval_every: 20000
# minimum_log_interval_secs: 1.0
# model:
#   name_or_path: EleutherAI/pythia-2.8b
#   tokenizer_name_or_path: null
#   archive: null
#   block_name: GPTNeoXLayer
#   policy_dtype: float32
#   fsdp_policy_mp: bfloat16
#   reference_dtype: float16
# loss:
#   name: sft
#
# ...

# %%
print("hello")
# Out:
# hello
