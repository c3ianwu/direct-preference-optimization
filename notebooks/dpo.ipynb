# %% [markdown]
# # DPO

# %%
# !/usr/local/nvidia/bin/nvidia-smi
# Out:
# Fri Jul 14 17:20:32 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.182.03   Driver Version: 470.182.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:80:00.0 Off |                    0 |
# | N/A   35C    P0    62W / 400W |      0MiB / 81251MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# ...

# %% [markdown]
# ## Train DPO
#
# The argument `model.archive` should point to the location of your SFT model. Leave it empty if you are training without SFT.

# %%
# !python -u train.py model=pythia28 datasets=[hh] loss=dpo loss.beta=0.1 exp_name=anthropic_dpo_pythia28 gradient_accumulation_steps=4 batch_size=32 eval_batch_size=32 trainer=FSDPTrainer sample_during_eval=false model.fsdp_policy_mp=bfloat16 model.archive=/home/c3/jupyter_root_dir/DPO/direct-preference-optimization/.cache/c3/anthropic_dpo_pythia28_2023-07-14_12-23-01_897813/step-140000/policy.pt
# Out:
# seed: 0
# exp_name: anthropic_dpo_pythia28
# batch_size: 32
# eval_batch_size: 32
# debug: false
# fsdp_port: 12355
# datasets:
# - hh
# wandb:
#   enabled: true
#   entity: ianyhwu
#   project: c3GenAI
# local_dirs:
# - /scr-ssd
# - /scr
# - .cache
# sample_during_eval: false
# n_eval_model_samples: 16
# do_first_eval: true
# local_run_dir: .cache/c3/anthropic_dpo_pythia28_2023-07-14_17-24-58_874842
# lr: 5.0e-07
# gradient_accumulation_steps: 4
# max_grad_norm: 10.0
# max_length: 512
# max_prompt_length: 256
# n_epochs: 1
# n_examples: null
# n_eval_examples: 256
# trainer: FSDPTrainer
# optimizer: RMSprop
# warmup_steps: 150
# activation_checkpointing: false
# eval_every: 20000
# minimum_log_interval_secs: 1.0
# model:
#   name_or_path: EleutherAI/pythia-2.8b
#   tokenizer_name_or_path: null
#   archive: /home/c3/jupyter_root_dir/DPO/direct-preference-optimization/.cache/c3/anthropic_dpo_pythia28_2023-07-14_12-23-01_897813/step-140000/policy.pt
#   block_name: GPTNeoXLayer
# ...

# %%
# Out:
# optimizer.pt  policy.pt  scheduler.pt
